# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set()

# %%
fly = pd.read_excel("data/lattice_fly.xlsx")
fly.drop(columns="Unnamed: 0", inplace=True)
fly.head()
# Out:
#    facet  temperature
# 0   8.07           15
# 1   8.07           15
# 2   8.07           15
# 3   7.07           15
# 4   7.07           15

# %%
sns.scatterplot(data=fly, x="temperature", y="facet")

# %% [markdown]
# #### Not working as expected

# %%
aggregates = fly.groupby("temperature", as_index=False).mean()
sns.stripplot(data=fly, x="temperature", y="facet", alpha=0.3, jitter=0.5, size=2)
zx = sns.scatterplot(data=aggregates, x="temperature", y="facet", color="black")

# %%
sns.scatterplot(data=fly, x="temperature", y="facet", alpha=0.5)
sns.scatterplot(data=aggregates, x="temperature", y="facet")

# %%
# Regplot + FacetGrid
sns.lmplot(x="temperature", y="facet", data=fly)
sns.scatterplot(data=aggregates, x="temperature", y="facet", color="black")

# %%
dating = pd.read_excel("data/dating_Mass.xlsx")
dating.head()
# Out:
#    carbon  thorium  age.diff
# 0    6.40     7.46      1.06
# 1    7.78     8.45      0.67
# 2    8.20     9.28      1.08
# 3    9.05     9.73      0.68
# 4    9.40    11.09      1.69

# %%
dating['y'] = dating['thorium'] - dating['carbon']
# sns.lmplot('carbon', 'y', data=dating, )
sns.lmplot('carbon', 'y', data=dating, robust=True, ci=50)
plt.ylabel('thorium - carbon')
# Out:
# Text(16.049999999999997, 0.5, 'thorium - carbon')

# %%
ganglion = pd.read_excel('data/ganglion_Mass.xlsx')
ganglion.head()
# Out:
#      area  cp_ratio
# 0  11.051  2.559758
# 1  13.865  2.816834
# 2  22.514  2.957259
# 3  32.810  3.422318
# 4  33.771  3.496610

# %%
sns.lmplot('area', 'cp_ratio', data=ganglion, lowess=True)

# %%
ganglion['log_cp_ratio'] = np.log(ganglion['cp_ratio'])
sns.lmplot('area', 'log_cp_ratio', data=ganglion)
